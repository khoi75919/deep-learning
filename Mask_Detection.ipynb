# %% [markdown]
# <a href="https://colab.research.google.com/github/khoi75919/deep-learning/blob/main/Mask_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf darknet
# %cd /content/drive/My Drive
# !git clone https://github.com/AlexeyAB/darknet
# %cd /content/drive/My Drive/darknet
# !rm -rf data
# !mkdir data
# Out:
# /content/drive/My Drive
# fatal: destination path 'darknet' already exists and is not an empty directory.
# /content/drive/My Drive/darknet

# %%
# %cd /content/drive/My Drive/darknet/data
# !unzip data.zip
# Out:
# /content/drive/My Drive/darknet/data
# Archive:  data.zip
#    creating: dataset/
#    creating: dataset/images/
#  extracting: dataset/images/classes.txt
#    creating: dataset/images/test/
#   inflating: dataset/images/test/nouveau-virus-en-chine-la-ville-de-wuhan-mise-en-quarantaine-1.jpg
#   inflating: dataset/images/test/nouveau-virus-en-chine-la-ville-de-wuhan-mise-en-quarantaine-1.txt
#   inflating: dataset/images/test/nq50003q8p6q8n72p7o.jpg
#   inflating: dataset/images/test/nq50003q8p6q8n72p7o.txt
#   inflating: dataset/images/test/nq50003q8p707o0p586.jpg
#   inflating: dataset/images/test/nq50003q8p707o0p586.txt
#   inflating: dataset/images/test/nqn000p326n081sq0np.jpg
#   inflating: dataset/images/test/nqn000p326n081sq0np.txt
#   inflating: dataset/images/test/nqn000p326o7525q707.jpg
#   inflating: dataset/images/test/nqn000p326o7525q707.txt
#   inflating: dataset/images/test/NUZZHAB7IMI6VHQQW44IVOMBHU.jpg
# ...

# %%
# %cd /content/drive/My Drive/darknet
# !echo "Mask" > yolo.names
# Out:
# /content/drive/My Drive/darknet

# %%
# %cd /content/drive/My Drive/darknet

import glob2
import math  
import os
import numpy as np

files = []
for ext in ["*.png", "*.jpeg", "*.jpg"]:
  image_files = glob2.glob(os.path.join("data/data/", ext))
  files += image_files

nb_val = math.floor(len(files)*0.2)
rand_idx = np.random.randint(0, len(files), nb_val)

# Tạo file train.txt
with open("train.txt", "w") as f:
  for idx in np.arange(len(files)):
    if (os.path.exists(files[idx][:-3] + "txt")):
      f.write(files[idx]+'\n')

# Tạo file vali.txt
with open("val.txt", "w") as f:
  for idx in np.arange(len(files)):
    if (idx in rand_idx) and (os.path.exists(files[idx][:-3] + "txt")):
      f.write(files[idx]+'\n')
# Out:
# /content/drive/My Drive/darknet

# %%
# %cd /content/drive/My Drive/darknet
# !mkdir backup
# !echo classes=1 > yolo.data
# !echo train=train.txt >> yolo.data
# !echo valid=val.txt >> yolo.data
# !echo names=yolo.names >> yolo.data
# !echo backup=backup >> yolo.data
# Out:
# /content/drive/My Drive/darknet

# %%
# %cd /content/drive/My Drive/darknet
# !rm darknet
# !make
# Out:
# /content/drive/My Drive/darknet
# rm: cannot remove 'darknet': No such file or directory
# mkdir -p ./obj/
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ...

# %%
# %cd /content/drive/My Drive/darknet
# !./darknet detector train yolo.data cfg/yolov4-custom.cfg yolov4_face_mask.weights -dont_show
# Out:
# /content/drive/My Drive/darknet
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# yolov4-custom
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    640 x 640 x   3 ->  640 x 640 x  32 0.708 BF
#    1 conv     64       3 x 3/ 2    640 x 640 x  32 ->  320 x 320 x  64 3.775 BF
#    2 conv     64       1 x 1/ 1    320 x 320 x  64 ->  320 x 320 x  64 0.839 BF
#    3 route  1 		                           ->  320 x 320 x  64
#    4 conv     64       1 x 1/ 1    320 x 320 x  64 ->  320 x 320 x  64 0.839 BF
#    5 conv     32       1 x 1/ 1    320 x 320 x  64 ->  320 x 320 x  32 0.419 BF
#    6 conv     64       3 x 3/ 1    320 x 320 x  32 ->  320 x 320 x  64 3.775 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 320 x 320 x  64 0.007 BF
# ...

# %%
# %cd /content/gdrive/My\ Drive/darknet
# !./darknet detector train yolo.data cfg/yolov4-custom.cfg yolov4-custom_final.weights -dont_show
# Out:
# [Errno 2] No such file or directory: '/content/gdrive/My Drive/darknet'
# /content/drive/My Drive/darknet
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# yolov4-custom
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    640 x 640 x   3 ->  640 x 640 x  32 0.708 BF
#    1 conv     64       3 x 3/ 2    640 x 640 x  32 ->  320 x 320 x  64 3.775 BF
#    2 conv     64       1 x 1/ 1    320 x 320 x  64 ->  320 x 320 x  64 0.839 BF
#    3 route  1 		                           ->  320 x 320 x  64
#    4 conv     64       1 x 1/ 1    320 x 320 x  64 ->  320 x 320 x  64 0.839 BF
#    5 conv     32       1 x 1/ 1    320 x 320 x  64 ->  320 x 320 x  32 0.419 BF
#    6 conv     64       3 x 3/ 1    320 x 320 x  32 ->  320 x 320 x  64 3.775 BF
# ...

# %%
 # !./darknet detector test obj.data yolov4.cfg yolov4_face_mask.weights input/virus.jpg -thresh 0.45
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# Couldn't open file: obj.data

# %% [markdown]
# https://www.miai.vn/2020/05/25/yolo-series-train-yolo-v4-train-tren-colab-chi-tiet-va-day-du-a-z/

# %% [markdown]
# https://github.com/adityap27/face-mask-detector
